# %%
3-1, 2번

# %%
import pandas as pd
df = pd.read_csv('/content/yourgoodpants_손유민(석사2).csv', sep=',')
print(df)
# Out:
#       Word    Time_s          F0_Hz
# 0     your  0.755086  --undefined--
# 1     your  0.766625  --undefined--
# 2     your  0.778163  --undefined--
# 3     your  0.789702     109.369817
# 4     your  0.801240     117.912689
# ..     ...       ...            ...
# 169  great  2.705086  --undefined--
# 170  great  2.716625  --undefined--
# 171  great  2.728163  --undefined--
# 172  great  2.739702  --undefined--
# 173  great  2.751240  --undefined--
#
# [174 rows x 3 columns]

# %%
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.F0_Hz == "--undefined--", "F0_Hz"] = None
print(df)
# Out:
#       Word    Time_s       F0_Hz
# 0     your  0.755086        None
# 1     your  0.766625        None
# 2     your  0.778163        None
# 3     your  0.789702  109.369817
# 4     your  0.801240  117.912689
# ..     ...       ...         ...
# 169  great  2.705086        None
# 170  great  2.716625        None
# 171  great  2.728163        None
# 172  great  2.739702        None
# 173  great  2.751240        None
#
# [174 rows x 3 columns]

# %%
time = df.Time_s
f0 = df.F0_Hz

plt.plot(time, f0, 'ro', label='pitch(Hz)')
plt.xlabel('time(sec)')
plt.ylabel('pitch(Hz)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()

# %%
3-1, 3번

# %%
import pandas as pd
df = pd.read_csv('/content/yourgoodpants_intensity_손유민(석사2).csv', sep=',')
print(df)
# Out:
#       Word    Time_s  Intensity_dB
# 0     your  0.752779     53.154894
# 1     your  0.765086     57.696765
# 2     your  0.777394     62.006203
# 3     your  0.789702     65.380577
# 4     your  0.802009     67.492633
# ..     ...       ...           ...
# 158  great  2.697394     33.292699
# 159  great  2.709702     28.748350
# 160  great  2.722009     27.873691
# 161  great  2.734317     28.773874
# 162  great  2.746625     28.360312
#
# [163 rows x 3 columns]

# %%
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.Intensity_dB == "--undefined--", "Intensity_dB"] = None
print(df)
# Out:
#       Word    Time_s  Intensity_dB
# 0     your  0.752779     53.154894
# 1     your  0.765086     57.696765
# 2     your  0.777394     62.006203
# 3     your  0.789702     65.380577
# 4     your  0.802009     67.492633
# ..     ...       ...           ...
# 158  great  2.697394     33.292699
# 159  great  2.709702     28.748350
# 160  great  2.722009     27.873691
# 161  great  2.734317     28.773874
# 162  great  2.746625     28.360312
#
# [163 rows x 3 columns]

# %%
time = df.Time_s
intensity = df.Intensity_dB

plt.plot(time, intensity, 'ro', label='intensity(dB)')
plt.xlabel('time(sec)')
plt.ylabel('intensity(dB)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()

# %%
3-1, 4번

# %%
import pandas as pd
df = pd.read_csv('/content/yourgoodpants_formants_손유민(석사2)_1.csv', sep=',')
print(df)
# Out:
#       Word    Time_s        F1_Hz        F2_Hz        F3_Hz        F4_Hz
# 0     your  0.750038  1568.473721  2868.131514  3937.793232  4711.136133
# 1     your  0.756288   248.784120  2450.755801  2982.391297  3104.427343
# 2     your  0.762538   273.326825  2505.271078  2982.638567  3006.392024
# 3     your  0.768788   271.701991  2462.152321  3026.444568  4075.423172
# 4     your  0.775038   253.641655  2509.500914  3063.617559  4212.697269
# ..     ...       ...          ...          ...          ...          ...
# 317  great  2.731288   972.029304  1884.539169  3213.539019  3894.940158
# 318  great  2.737538  1250.022655  1913.062694  3181.039910  3995.303966
# 319  great  2.743788   928.261562  1980.735070  3149.054012  4343.644375
# 320  great  2.750038   944.644867  2110.545013  3342.803892  4397.992789
# 321  great  2.756288   975.748657  2075.878790  3211.635966  4162.910074
#
# [322 rows x 6 columns]

# %%
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.F1_Hz == "--undefined--", "F1_Hz"] = None
df.loc[df.F2_Hz == "--undefined--", "F2_Hz"] = None
df.loc[df.F3_Hz == "--undefined--", "F3_Hz"] = None
df.loc[df.F4_Hz == "--undefined--", "F4_Hz"] = None
print(df)
# Out:
#       Word    Time_s        F1_Hz        F2_Hz        F3_Hz        F4_Hz
# 0     your  0.750038  1568.473721  2868.131514  3937.793232  4711.136133
# 1     your  0.756288   248.784120  2450.755801  2982.391297  3104.427343
# 2     your  0.762538   273.326825  2505.271078  2982.638567  3006.392024
# 3     your  0.768788   271.701991  2462.152321  3026.444568  4075.423172
# 4     your  0.775038   253.641655  2509.500914  3063.617559  4212.697269
# ..     ...       ...          ...          ...          ...          ...
# 317  great  2.731288   972.029304  1884.539169  3213.539019  3894.940158
# 318  great  2.737538  1250.022655  1913.062694  3181.039910  3995.303966
# 319  great  2.743788   928.261562  1980.735070  3149.054012  4343.644375
# 320  great  2.750038   944.644867  2110.545013  3342.803892  4397.992789
# 321  great  2.756288   975.748657  2075.878790  3211.635966  4162.910074
#
# [322 rows x 6 columns]

# %%
time = df.Time_s
f1 = df.F1_Hz
f2 = df.F2_Hz
f3 = df.F3_Hz
f4 = df.F4_Hz

plt.plot(time, f1, 'ro', label='F1 (Hz)')
plt.plot(time, f2, 'bo', label='F2 (Hz)')
plt.plot(time, f3, 'go', label='F3 (Hz)')
plt.plot(time, f4, 'yo', label='F4 (Hz)')
plt.xlabel('Time(s)')
plt.ylabel('frequency(Hz)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()
